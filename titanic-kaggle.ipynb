# %%
import pandas as pd

# %%
df=pd.read_csv('./Titanic/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Feature Engineering

# %%
df2=df.drop(['Name','Ticket','Fare'],axis=1)
df2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1         0       3    male  22.0      1      0   NaN        S
# 1            2         1       1  female  38.0      1      0   C85        C
# 2            3         1       3  female  26.0      0      0   NaN        S
# 3            4         1       1  female  35.0      1      0  C123        S
# 4            5         0       3    male  35.0      0      0   NaN        S

# %%
df2=df2.drop('Embarked',axis=1)
df2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin
# 0            1         0       3    male  22.0      1      0   NaN
# 1            2         1       1  female  38.0      1      0   C85
# 2            3         1       3  female  26.0      0      0   NaN
# 3            4         1       1  female  35.0      1      0  C123
# 4            5         0       3    male  35.0      0      0   NaN

# %%
df2=df2.fillna(value=0)
df2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0            1         0       3    male  22.0      1      0     0        S
# 1            2         1       1  female  38.0      1      0   C85        C
# 2            3         1       3  female  26.0      0      0     0        S
# 3            4         1       1  female  35.0      1      0  C123        S
# 4            5         0       3    male  35.0      0      0     0        S

# %%
df3=df2.copy()
df3['Cabin']=df3['Cabin'].apply(lambda x: 1 if(x!=0) else 0)
df3.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  Cabin Embarked
# 0            1         0       3    male  22.0      1      0      0        S
# 1            2         1       1  female  38.0      1      0      1        C
# 2            3         1       3  female  26.0      0      0      0        S
# 3            4         1       1  female  35.0      1      0      1        S
# 4            5         0       3    male  35.0      0      0      0        S

# %%
df4=df3.copy()
df4['Sex']=df3['Sex'].apply(lambda x: 1 if(x=='female') else 0)
df4.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  Cabin Embarked
# 0            1         0       3    0  22.0      1      0      0        S
# 1            2         1       1    1  38.0      1      0      1        C
# 2            3         1       3    1  26.0      0      0      0        S
# 3            4         1       1    1  35.0      1      0      1        S
# 4            5         0       3    0  35.0      0      0      0        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df5=df4.copy()
mea=df['Age'].mean()
df5['Age']=df5['Age'].apply(lambda x: mea if(x==0) else x)
df5.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch  Cabin Embarked
# 0            1         0       3    0  22.000000      1      0      0        S
# 1            2         1       1    1  38.000000      1      0      1        C
# 2            3         1       3    1  26.000000      0      0      0        S
# 3            4         1       1    1  35.000000      1      0      1        S
# 4            5         0       3    0  35.000000      0      0      0        S
# 5            6         0       3    0  29.699118      0      0      0        Q
# 6            7         0       1    0  54.000000      0      0      1        S
# 7            8         0       3    0   2.000000      3      1      0        S
# 8            9         1       3    1  27.000000      0      2      0        S
# 9           10         1       2    1  14.000000      1      0      0        C

# %%
df6=df5.copy()
df6=df6.drop('PassengerId',axis=1)
df6.head()
df6['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', 0], dtype=object)

# %% [markdown]
# ## Handling categorial features

# %%
df7=df6.copy()
dummy=pd.get_dummies(df7['Embarked'],drop_first=True)
df7=pd.concat([df7,dummy],axis='columns')
from sklearn.model_selection import train_test_split as tts
df7=df7.drop('Embarked',axis=1)

# %%
x1,x2,y1,y2=tts(df6.drop('Survived',axis=1),df6[['Survived']],test_size=0.2)

# %% [markdown]
# ## Model Selection

# %%
from sklearn.ensemble import RandomForestClassifier as lr
model1=lr()
model1.fit(x1,y1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-c917e129c139> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier as lr
#       2 model1=lr()
# ----> 3 model1.fit(x1,y1)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     293         """
#     294         # Validate or convert input data
# --> 295         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     296         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     297         if sample_weight is not None:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
# ...

# %%
model1.score(x2,y2)
# Out:
# 0.8212290502793296

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
cv=ShuffleSplit(n_splits=5,random_state=0,test_size=0.2)
cross_val_score(lr(),x1,y1,cv=cv)
# Out:
# C:\Users\bmkr5\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\bmkr5\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\bmkr5\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %% [markdown]
# ## Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import ShuffleSplit
from sklearn.svm import SVC
def gscv(X,Y):
    algos={
        'RandomForestClassifier':{
            'model':lr(),
            'params':{
                'n_estimators': [100,200]
            }
        },
        'lasso':{
            'model':Lasso(),
            'params':{
                'alpha':[1,2],
                'selection':['random','cyclic']
            }
        },
        'decision_tree':{
            'model':SVC(),
            'params':{
                'kernel': ['rbf','poly'],
                'gamma':['scale','auto']
            }
        }
    }
    scores=[]
    cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algo_name,config in algos.items():
        gs=GridSearchCV(config['model'],config['params'],cv=cv,return_train_score=False)
        gs.fit(X,Y)
        scores.append({
            'model':algo_name,
            'best_score':gs.best_score_,
            'best_params':gs.best_params_
        })
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression as lor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVC
def gscv2(X,Y):
    algos={
        'LogisticRegression':{
            'model':lor(),
            'params':{
                'C': [1,2,3],
                'tol': [0.0001,0.001,0.00001]
            }
        }
    }
    scores=[]
    cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algo_name,config in algos.items():
        gs=GridSearchCV(config['model'],config['params'],cv=cv,return_train_score=False)
        gs.fit(X,Y)
        scores.append({
            'model':algo_name,
            'best_score':gs.best_score_,
            'best_params':gs.best_params_
        })
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

# %%
x3,y3=tts(df7)

# %%
gscv2(x3.drop('Survived',axis=1),x3[['Survived']])
# Out:
# C:\Users\bmkr5\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\bmkr5\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\bmkr5\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
y3.head()
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Cabin
# 833         0       3    0  23.0      0      0      0
# 106         1       3    1  21.0      0      0      0
# 754         1       2    1  48.0      1      2      0
# 575         0       3    0  19.0      0      0      0
# 830         1       3    1  15.0      1      0      0

# %%
model1=lr()
model1.fit(df6.drop('Survived',axis=1),df6[['Survived']])
# Out:
# C:\Users\bmkr5\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
df7=pd.read_csv('./Titanic/test.csv')

# %% [markdown]
# ## Test data preprocessing(same as train data)

# %%
df7=df7.drop(['Name','Ticket','Fare','Embarked'],axis=1)
df7.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch Cabin
# 0          892       3    male  34.5      0      0   NaN
# 1          893       3  female  47.0      1      0   NaN
# 2          894       2    male  62.0      0      0   NaN
# 3          895       3    male  27.0      0      0   NaN
# 4          896       3  female  22.0      1      1   NaN

# %%
df7=df7.fillna(0)

# %%
mea2=df7['Age'].mean()
df7['Age']=df7['Age'].apply(lambda x: mea2 if(x==0) else x)

# %%
df7['Sex']=df7['Sex'].apply(lambda x: 1 if(x=='Male') else 0)

# %%
df7.drop('PassengerId',axis=1,inplace=True)
df7.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch Cabin
# 0       3    0  34.5      0      0     0
# 1       3    0  47.0      1      0     0
# 2       2    0  62.0      0      0     0
# 3       3    0  27.0      0      0     0
# 4       3    0  22.0      1      1     0

# %%
df7['Cabin']=df7['Cabin'].apply(lambda x: 1 if(x!=0) else 0)

# %%
pred=model.predict(df7)

# %%
df9=pd.DataFrame(pred)
df9=pd.concat([df8['PassengerId'],df9],axis='columns')
df9.head()
# Out:
#    PassengerId  0
# 0          892  0
# 1          893  0
# 2          894  0
# 3          895  0
# 4          896  0

# %%
df9.to_csv('./Titanic/solution.csv',index=False)

# %%
df9.columns=['PassengerId','Survived']

# %%
df9['Survived']=df9['Survived'].apply(lambda x: 1 if(x>=0.5) else 0)
df9.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %% [markdown]
# ## Removal of outliers

# %%
from scipy.stats import zscore

# %%
import numpy as np
z=np.abs(zscore(df7))
# Out:
# C:\Users\bmkr5\anaconda3\lib\site-packages\scipy\stats\stats.py:2419: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
z=np.nan_to_num(z,nan=0)

# %%
df7=df7[(z<3).all(axis=1)]
df7.shape
# Out:
# (499, 7)

# %%
from sklearn.linear_model import LogisticRegression as Lor
model=Lor()

# %%
model.fit(df7.drop('Survived',axis=1),df7[['Survived']])
# Out:
# C:\Users\bmkr5\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
q1=df6.quantile(0.25)
q3=df6.quantile(0.75)
iqr=q3-q1

# %%
df7=df6[~((df6<(q1-1.5*iqr))|(df6>(q3+1.5*iqr))).any(axis=1)]
df7.shape
# Out:
# (517, 7)

# %%
df6.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch  Cabin
# 0         0       3    0  22.0      1      0      0
# 1         1       1    1  38.0      1      0      1
# 2         1       3    1  26.0      0      0      0
# 3         1       1    1  35.0      1      0      1
# 4         0       3    0  35.0      0      0      0
